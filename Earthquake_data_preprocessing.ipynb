# %% [markdown]
# # Data preprocessing

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import xgboost as xgb
sns.set_style('darkgrid')
# %matplotlib inline

# %%
df_train = pd.read_csv('train_values.csv')
df_train_lb = pd.read_csv('train_labels.csv')
df_test = pd.read_csv('test_values.csv')

# %%
df_train.head()
# Out:
#    building_id  geo_level_1_id  geo_level_2_id  geo_level_3_id  \
# 0       802906               6             487           12198
# 1        28830               8             900            2812
# 2        94947              21             363            8973
# 3       590882              22             418           10694
# 4       201944              11             131            1488
#
#    count_floors_pre_eq  age  area_percentage  height_percentage  \
# 0                    2   30                6                  5
# 1                    2   10                8                  7
# 2                    2   10                5                  5
# 3                    2   10                6                  5
# 4                    3   30                8                  9
#
#   land_surface_condition foundation_type           ...             \
# 0                      t               r           ...
# 1                      o               r           ...
# ...

# %%
# Target variable is damage_grade
df_train_lb.head()
# Out:
#    building_id  damage_grade
# 0       802906             3
# 1        28830             2
# 2        94947             3
# 3       590882             2
# 4       201944             3

# %%
df_test.head()
# Out:
#    building_id  geo_level_1_id  geo_level_2_id  geo_level_3_id  \
# 0       300051              17             596           11307
# 1        99355               6             141           11987
# 2       890251              22              19           10044
# 3       745817              26              39             633
# 4       421793              17             289            7970
#
#    count_floors_pre_eq  age  area_percentage  height_percentage  \
# 0                    3   20                7                  6
# 1                    2   25               13                  5
# 2                    2    5                4                  5
# 3                    1    0               19                  3
# 4                    3   15                8                  7
#
#   land_surface_condition foundation_type           ...             \
# 0                      t               r           ...
# 1                      t               r           ...
# ...

# %%
df = df_train.set_index('building_id').join(df_train_lb.set_index('building_id'))

# %%
df.isnull().sum()
# Out:
# geo_level_1_id                            0
# geo_level_2_id                            0
# geo_level_3_id                            0
# count_floors_pre_eq                       0
# age                                       0
# area_percentage                           0
# height_percentage                         0
# land_surface_condition                    0
# foundation_type                           0
# roof_type                                 0
# ground_floor_type                         0
# other_floor_type                          0
# position                                  0
# plan_configuration                        0
# has_superstructure_adobe_mud              0
# has_superstructure_mud_mortar_stone       0
# has_superstructure_stone_flag             0
# has_superstructure_cement_mortar_stone    0
# has_superstructure_mud_mortar_brick       0
# has_superstructure_cement_mortar_brick    0
# has_superstructure_timber                 0
# ...

# %%
df.describe()
# Out:
#        geo_level_1_id  geo_level_2_id  geo_level_3_id  count_floors_pre_eq  \
# count   260601.000000   260601.000000   260601.000000        260601.000000
# mean        13.900353      701.074685     6257.876148             2.129723
# std          8.033617      412.710734     3646.369645             0.727665
# min          0.000000        0.000000        0.000000             1.000000
# 25%          7.000000      350.000000     3073.000000             2.000000
# 50%         12.000000      702.000000     6270.000000             2.000000
# 75%         21.000000     1050.000000     9412.000000             2.000000
# max         30.000000     1427.000000    12567.000000             9.000000
#
#                  age  area_percentage  height_percentage  \
# count  260601.000000    260601.000000      260601.000000
# mean       26.535029         8.018051           5.434365
# std        73.565937         4.392231           1.918418
# min         0.000000         1.000000           2.000000
# ...

# %%
df.shape
# Out:
# (260601, 39)

# %%
df.columns
# Out:
# Index(['geo_level_1_id', 'geo_level_2_id', 'geo_level_3_id',
#        'count_floors_pre_eq', 'age', 'area_percentage', 'height_percentage',
#        'land_surface_condition', 'foundation_type', 'roof_type',
#        'ground_floor_type', 'other_floor_type', 'position',
#        'plan_configuration', 'has_superstructure_adobe_mud',
#        'has_superstructure_mud_mortar_stone', 'has_superstructure_stone_flag',
#        'has_superstructure_cement_mortar_stone',
#        'has_superstructure_mud_mortar_brick',
#        'has_superstructure_cement_mortar_brick', 'has_superstructure_timber',
#        'has_superstructure_bamboo', 'has_superstructure_rc_non_engineered',
#        'has_superstructure_rc_engineered', 'has_superstructure_other',
#        'legal_ownership_status', 'count_families', 'has_secondary_use',
#        'has_secondary_use_agriculture', 'has_secondary_use_hotel',
#        'has_secondary_use_rental', 'has_secondary_use_institution',
# ...

# %%
column_list = df.columns
binary = []

for col in column_list:
    if len(df[col].unique()) == 2:
        binary.append(col)

# %%
print('Binary column count: ',len(binary))
binary
# Out:
# Binary column count:  22
# ['has_superstructure_adobe_mud',
#  'has_superstructure_mud_mortar_stone',
#  'has_superstructure_stone_flag',
#  'has_superstructure_cement_mortar_stone',
#  'has_superstructure_mud_mortar_brick',
#  'has_superstructure_cement_mortar_brick',
#  'has_superstructure_timber',
#  'has_superstructure_bamboo',
#  'has_superstructure_rc_non_engineered',
#  'has_superstructure_rc_engineered',
#  'has_superstructure_other',
#  'has_secondary_use',
#  'has_secondary_use_agriculture',
#  'has_secondary_use_hotel',
#  'has_secondary_use_rental',
#  'has_secondary_use_institution',
#  'has_secondary_use_school',
#  'has_secondary_use_industry',
#  'has_secondary_use_health_post',
#  'has_secondary_use_gov_office',
#  'has_secondary_use_use_police',
#  'has_secondary_use_other']

# %%
other_col = []
for col in column_list:
    other_col.append(col)

# %%
for col in binary:
    other_col.remove(col)

# %%
sns.heatmap(df.corr())

# %%
sns.heatmap(df[other_col].corr())

# %%
sns.heatmap(df[binary].corr())

# %%
df[binary].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 260601 entries, 802906 to 747594
# Data columns (total 22 columns):
# has_superstructure_adobe_mud              260601 non-null int64
# has_superstructure_mud_mortar_stone       260601 non-null int64
# has_superstructure_stone_flag             260601 non-null int64
# has_superstructure_cement_mortar_stone    260601 non-null int64
# has_superstructure_mud_mortar_brick       260601 non-null int64
# has_superstructure_cement_mortar_brick    260601 non-null int64
# has_superstructure_timber                 260601 non-null int64
# has_superstructure_bamboo                 260601 non-null int64
# has_superstructure_rc_non_engineered      260601 non-null int64
# has_superstructure_rc_engineered          260601 non-null int64
# has_superstructure_other                  260601 non-null int64
# has_secondary_use                         260601 non-null int64
# has_secondary_use_agriculture             260601 non-null int64
# ...

# %%
df[other_col].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 260601 entries, 802906 to 747594
# Data columns (total 17 columns):
# geo_level_1_id            260601 non-null int64
# geo_level_2_id            260601 non-null int64
# geo_level_3_id            260601 non-null int64
# count_floors_pre_eq       260601 non-null int64
# age                       260601 non-null int64
# area_percentage           260601 non-null int64
# height_percentage         260601 non-null int64
# land_surface_condition    260601 non-null object
# foundation_type           260601 non-null object
# roof_type                 260601 non-null object
# ground_floor_type         260601 non-null object
# other_floor_type          260601 non-null object
# position                  260601 non-null object
# plan_configuration        260601 non-null object
# legal_ownership_status    260601 non-null object
# count_families            260601 non-null int64
# damage_grade              260601 non-null int64
# ...

# %%
object_col = []

for col in other_col:
    if df.dtypes[col] == np.object:
        object_col.append(col)

# %%
object_col
# Out:
# ['land_surface_condition',
#  'foundation_type',
#  'roof_type',
#  'ground_floor_type',
#  'other_floor_type',
#  'position',
#  'plan_configuration',
#  'legal_ownership_status']

# %%
for col in object_col:
    print(col,'unique value count :', len(df[col].unique()))
# Out:
# land_surface_condition unique value count : 3
# foundation_type unique value count : 5
# roof_type unique value count : 3
# ground_floor_type unique value count : 5
# other_floor_type unique value count : 4
# position unique value count : 4
# plan_configuration unique value count : 10
# legal_ownership_status unique value count : 4

# %% [markdown]
# ## Create dummy variables for object data type (Training)

# %%
dummy_variable = pd.get_dummies(df[object_col], drop_first=True)

# %%
dummy_variable.head()
# Out:
#              land_surface_condition_o  land_surface_condition_t  \
# building_id
# 802906                              0                         1
# 28830                               1                         0
# 94947                               0                         1
# 590882                              0                         1
# 201944                              0                         1
#
#              foundation_type_i  foundation_type_r  foundation_type_u  \
# building_id
# 802906                       0                  1                  0
# 28830                        0                  1                  0
# 94947                        0                  1                  0
# 590882                       0                  1                  0
# 201944                       0                  1                  0
#
#              foundation_type_w  roof_type_q  roof_type_x  ground_floor_type_m  \
# building_id
# ...

# %%
df.drop(columns=object_col, inplace=True)

# %%
df = pd.concat([df, dummy_variable], axis=1)

# %%
df.shape
# Out:
# (260601, 61)

# %%
df.head()
# Out:
#              geo_level_1_id  geo_level_2_id  geo_level_3_id  \
# building_id
# 802906                    6             487           12198
# 28830                     8             900            2812
# 94947                    21             363            8973
# 590882                   22             418           10694
# 201944                   11             131            1488
#
#              count_floors_pre_eq  age  area_percentage  height_percentage  \
# building_id
# 802906                         2   30                6                  5
# 28830                          2   10                8                  7
# 94947                          2   10                5                  5
# 590882                         2   10                6                  5
# 201944                         3   30                8                  9
#
#              has_superstructure_adobe_mud  \
# building_id
# 802906                                  1
# ...

# %% [markdown]
# ## Create dummy variables for object data type (Test)
# This is for later submission

# %%
df_test_cp = df_test.copy()

# %%
df_test_cp.shape
# Out:
# (86868, 39)

# %%
dummy_variable = pd.get_dummies(df_test_cp[object_col], drop_first=True)
df_test_cp.drop(columns=object_col, inplace=True)
df_test_cp = pd.concat([df_test_cp, dummy_variable], axis=1)

# %%
df.shape
# Out:
# (260601, 61)

# %%
df_test_cp.shape
# Out:
# (86868, 61)

# %%
df.head()
# Out:
#              geo_level_1_id  geo_level_2_id  geo_level_3_id  \
# building_id
# 802906                    6             487           12198
# 28830                     8             900            2812
# 94947                    21             363            8973
# 590882                   22             418           10694
# 201944                   11             131            1488
#
#              count_floors_pre_eq  age  area_percentage  height_percentage  \
# building_id
# 802906                         2   30                6                  5
# 28830                          2   10                8                  7
# 94947                          2   10                5                  5
# 590882                         2   10                6                  5
# 201944                         3   30                8                  9
#
#              has_superstructure_adobe_mud  \
# building_id
# 802906                                  1
# ...

# %%
df_test_cp.head()
# Out:
#    building_id  geo_level_1_id  geo_level_2_id  geo_level_3_id  \
# 0       300051              17             596           11307
# 1        99355               6             141           11987
# 2       890251              22              19           10044
# 3       745817              26              39             633
# 4       421793              17             289            7970
#
#    count_floors_pre_eq  age  area_percentage  height_percentage  \
# 0                    3   20                7                  6
# 1                    2   25               13                  5
# 2                    2    5                4                  5
# 3                    1    0               19                  3
# 4                    3   15                8                  7
#
#    has_superstructure_adobe_mud  has_superstructure_mud_mortar_stone  \
# 0                             0                                    1
# ...

# %% [markdown]
# ## Save train and test dataset

# %%
df.to_csv('train_ready.csv')
df_test_cp.to_csv('test_ready.csv', index = False)
