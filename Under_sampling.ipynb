# %% [markdown]
# # Approach: Under Sampling

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('darkgrid')
# %matplotlib inline

from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.model_selection import train_test_split
import xgboost as xgb

# %%
df_train = pd.read_csv('stand_train.csv', index_col='building_id')
df_test = pd.read_csv('stand_test.csv', index_col='building_id')

# %%
len(df_train)
# Out:
# 260601

# %%
len(df_test)
# Out:
# 86868

# %%
df_train['damage_grade'].value_counts()
# Out:
# 2    148259
# 3     87218
# 1     25124
# Name: damage_grade, dtype: int64

# %% [markdown]
# ## Split data by damage

# %%
damage_1 = df_train[df_train['damage_grade'] == 1]
damage_2 = df_train[df_train['damage_grade'] == 2]
damage_3 = df_train[df_train['damage_grade'] == 3]

# %%
damage_1.head()
# Out:
#              geo_level_1_id  geo_level_2_id  geo_level_3_id  \
# building_id
# 475515             0.759267       -0.916078        1.639476
# 989500             1.506130        0.448076       -1.443596
# 864809            -0.112073       -0.959693       -0.082788
# 440102            -0.858937       -1.318298       -0.272292
# 402996             1.506130        0.147623       -1.512706
#
#              count_floors_pre_eq       age  area_percentage  \
# building_id
# 475515                 -0.178274 -0.360698        -0.004110
# 989500                 -1.552536 -0.360698         1.134266
# 864809                 -0.178274 -0.360698         0.223565
# 440102                 -1.552536 -0.292732         0.678916
# 402996                 -1.552536 -0.360698         1.589617
#
#              height_percentage  count_families  has_superstructure_adobe_mud  \
# building_id
# 475515                0.294845        0.038365                             0
# 989500               -0.747683        0.038365                             0
# 864809                1.337372        0.038365                             0
# 440102               -1.268946        2.428490                             0
# 402996               -1.268946        0.038365                             0
#
#              has_superstructure_mud_mortar_stone            ...             \
# building_id                                                 ...
# 475515                                         0            ...
# 989500                                         0            ...
# 864809                                         1            ...
# 440102                                         0            ...
# 402996                                         1            ...
#
#              plan_configuration_f  plan_configuration_m  plan_configuration_n  \
# building_id
# 475515                          0                     0                     0
# 989500                          0                     0                     0
# 864809                          0                     0                     0
# 440102                          0                     0                     0
# 402996                          0                     0                     0
#
#              plan_configuration_o  plan_configuration_q  plan_configuration_s  \
# building_id
# 475515                          0                     0                     0
# 989500                          0                     0                     0
# 864809                          0                     0                     0
# 440102                          0                     0                     0
# 402996                          0                     0                     0
#
#              plan_configuration_u  legal_ownership_status_r  \
# building_id
# 475515                          1                         0
# 989500                          0                         0
# 864809                          0                         0
# 440102                          0                         0
# 402996                          0                         0
#
#              legal_ownership_status_v  legal_ownership_status_w
# building_id
# 475515                              1                         0
# 989500                              1                         0
# 864809                              1                         0
# 440102                              1                         0
# 402996                              1                         0
#
# [5 rows x 61 columns]

# %%
damage_2.head()
# Out:
#              geo_level_1_id  geo_level_2_id  geo_level_3_id  \
# building_id
# 28830             -0.734459        0.481998       -0.945017
# 590882             1.008221       -0.685893        1.216589
# 333020            -0.734459       -0.346671       -0.046314
# 441126            -1.730277        0.135508        0.263584
# 452227             0.385835        1.390626       -0.618116
#
#              count_floors_pre_eq       age  area_percentage  \
# building_id
# 28830                  -0.178274 -0.224765        -0.004110
# 590882                 -0.178274 -0.224765        -0.459460
# 333020                 -0.178274 -0.224765         0.223565
# 441126                 -0.178274 -0.156799        -0.004110
# 452227                 -1.552536 -0.224765        -0.004110
#
#              height_percentage  count_families  has_superstructure_adobe_mud  \
# building_id
# 28830                 0.816109        0.038365                             0
# 590882               -0.226419        0.038365                             0
# 333020               -0.226419        0.038365                             0
# 441126                0.294845        0.038365                             0
# 452227               -0.747683        0.038365                             0
#
#              has_superstructure_mud_mortar_stone            ...             \
# building_id                                                 ...
# 28830                                          1            ...
# 590882                                         1            ...
# 333020                                         1            ...
# 441126                                         1            ...
# 452227                                         0            ...
#
#              plan_configuration_f  plan_configuration_m  plan_configuration_n  \
# building_id
# 28830                           0                     0                     0
# 590882                          0                     0                     0
# 333020                          0                     0                     0
# 441126                          0                     0                     0
# 452227                          0                     0                     0
#
#              plan_configuration_o  plan_configuration_q  plan_configuration_s  \
# building_id
# 28830                           0                     0                     0
# 590882                          0                     0                     0
# 333020                          0                     0                     0
# 441126                          0                     0                     0
# 452227                          0                     0                     0
#
#              plan_configuration_u  legal_ownership_status_r  \
# building_id
# 28830                           0                         0
# 590882                          0                         0
# 333020                          0                         0
# 441126                          0                         0
# 452227                          0                         0
#
#              legal_ownership_status_v  legal_ownership_status_w
# building_id
# 28830                               1                         0
# 590882                              1                         0
# 333020                              1                         0
# 441126                              1                         0
# 452227                              0                         0
#
# [5 rows x 61 columns]

# %%
damage_3.head()
# Out:
#              geo_level_1_id  geo_level_2_id  geo_level_3_id  \
# building_id
# 802906            -0.983414       -0.518705        1.629055
# 94947              0.883744       -0.819158        0.744612
# 201944            -0.361028       -1.381296       -1.308119
# 728451            -0.609982       -0.547781        1.592854
# 7962               0.385835        1.012637        1.626312
#
#              count_floors_pre_eq       age  area_percentage  \
# building_id
# 802906                 -0.178274  0.047100        -0.459460
# 94947                  -0.178274 -0.224765        -0.687135
# 201944                  1.195989  0.047100        -0.004110
# 728451                 -0.178274 -0.020866        -1.142486
# 7962                   -0.178274 -0.088832         0.223565
#
#              height_percentage  count_families  has_superstructure_adobe_mud  \
# building_id
# 802906               -0.226419        0.038365                             1
# 94947                -0.226419        0.038365                             0
# 201944                1.858636        0.038365                             1
# 728451               -0.747683        0.038365                             0
# 7962                  0.294845        0.038365                             0
#
#              has_superstructure_mud_mortar_stone            ...             \
# building_id                                                 ...
# 802906                                         1            ...
# 94947                                          1            ...
# 201944                                         0            ...
# 728451                                         1            ...
# 7962                                           1            ...
#
#              plan_configuration_f  plan_configuration_m  plan_configuration_n  \
# building_id
# 802906                          0                     0                     0
# 94947                           0                     0                     0
# 201944                          0                     0                     0
# 728451                          0                     0                     0
# 7962                            0                     0                     0
#
#              plan_configuration_o  plan_configuration_q  plan_configuration_s  \
# building_id
# 802906                          0                     0                     0
# 94947                           0                     0                     0
# 201944                          0                     0                     0
# 728451                          0                     0                     0
# 7962                            0                     0                     0
#
#              plan_configuration_u  legal_ownership_status_r  \
# building_id
# 802906                          0                         0
# 94947                           0                         0
# 201944                          0                         0
# 728451                          0                         0
# 7962                            0                         0
#
#              legal_ownership_status_v  legal_ownership_status_w
# building_id
# 802906                              1                         0
# 94947                               1                         0
# 201944                              1                         0
# 728451                              1                         0
# 7962                                1                         0
#
# [5 rows x 61 columns]

# %%
# Shuffle the dataframe before under sampling to prevent selection bias

from sklearn.utils import shuffle

# %%
damage1= shuffle(damage_1)
damage2= shuffle(damage_2)
damage3= shuffle(damage_3)

# %%
damage2 = damage2.iloc[:70000]
damage3 = damage3.iloc[:40000]

# %%
print(len(damage1))
print(len(damage2))
print(len(damage3))
# Out:
# 25124
# 70000
# 40000

# %%
df_train = pd.concat([damage1, damage2, damage3], axis=0)

# %%
df_train = shuffle(df_train)

# %%
df_train.to_csv('under_train.csv')

# %% [markdown]
# ## Train test split

# %%
X = df_train.drop(columns=['damage_grade'])
y = df_train['damage_grade']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=101)

# %% [markdown]
# ## Model fitting

# %%
classifier = xgb.XGBClassifier(objective='multi:softmax', num_class=3, learning_rate=0.02,max_depth=10, nfold=5, seed=101)

# %%
classifier.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bynode=1, colsample_bytree=1, gamma=0, learning_rate=0.02,
#        max_delta_step=0, max_depth=10, min_child_weight=1, missing=None,
#        n_estimators=100, n_jobs=1, nfold=5, nthread=None, num_class=3,
#        objective='multi:softprob', random_state=0, reg_alpha=0,
#        reg_lambda=1, scale_pos_weight=1, seed=101, silent=None,
#        subsample=1, verbosity=1)

# %%
y_pred = classifier.predict(X_test)
# Out:
# C:\Users\chi\Anaconda3\envs\py36\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:

# %%
print(classification_report(y_test, y_pred))
# Out:
#              precision    recall  f1-score   support
#
#           1       0.72      0.59      0.65      7434
#           2       0.67      0.82      0.74     20969
#           3       0.73      0.53      0.62     12135
#
# avg / total       0.70      0.69      0.68     40538

# %%
print(accuracy_score(y_test, y_pred))
# Out:
# 0.6908579604321871

# %% [markdown]
# ## Submission

# %%
submit = pd.read_csv('submission_format.csv', index_col='building_id')

# %%
submit.head()
# Out:
#              damage_grade
# building_id
# 300051                  1
# 99355                   1
# 890251                  1
# 745817                  1
# 421793                  1

# %%
submit.drop(columns=['damage_grade'], inplace=True)

# %%
submit['damage_grade'] = classifier.predict(df_test)
# Out:
# C:\Users\chi\Anaconda3\envs\py36\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:

# %%
submit.head()
# Out:
#              damage_grade
# building_id
# 300051                  3
# 99355                   2
# 890251                  2
# 745817                  1
# 421793                  3

# %%
submit.to_csv('under_submit.csv')

# %% [markdown]
# ## under sampling did not improve model

# %% [markdown]
# # Next approach:
# * Oversampling using SMOTE
